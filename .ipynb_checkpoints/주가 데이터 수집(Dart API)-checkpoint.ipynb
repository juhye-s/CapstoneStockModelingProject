# %% [markdown]
# # Dart API로 재무제표 가져오기

# %%
# 개발 가이드 https://opendart.fss.or.kr/guide/main.do?apiGrpCd=DS001
# 키 ef1bb5ab681bc62b16ac450a6fc77cad65cd61a6
# 개발 가이드 더 상세 https://dart-fss.readthedocs.io/en/latest/dart_fs.html

import dart_fss as dart

# Open DART API KEY 설정
api_key='ef1bb5ab681bc62b16ac450a6fc77cad65cd61a6'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자 검색
samsung = corp_list.find_by_corp_name('삼성전자', exactly=True)[0]

# 2022년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20130101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
# fs.save()
# Out:
# Annual reports:   0%|          | 0/11 [00:00<?, ?report/s]

# %% [markdown]
# ## 데이터 정리
#
# ### 연결재무제표
# - 지배기업의 재무제표 수치에 종속기업 수치까지 합산해서 작성한 것
# - 일반적으로 우리가 재무제표를 본다고 하면 연결재무제표다.
# - fs['bs']

# %%
fs['bs'].iloc[:,[1]]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                          label_ko
# 0                                                유동자산
# 1                                            현금및현금성자산
# 2                                              단기금융상품
# 3                                         단기상각후원가금융자산
# 4                                     단기당기손익-공정가치금융자산
# 5                                                매출채권
# 6                                                 미수금
# 7                                                선급비용
# 8                                                재고자산
# 9                                              기타유동자산
# 10                                           매각예정분류자산
# 11                                              비유동자산
# 12                                    기타포괄손익-공정가치금융자산
# ...

# %%
fs['bs']

# %% [markdown]
# ## 연결손익계산서
#
# - 지배, 종속관계에 있는 기업 집단이 일정 회계기간 동안 거둔 총체적인 경영실적을 나타낸 것
# - 손익계산서에서 아래와 같은 정보를 확인할 수 있다.
# - 영업 이익률 = 영업이익/매출액 * 100

# %%
fs['is'].iloc[:,[1]]
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)
#                                                                                              label_ko
# 0                                             수익(매출액)
# 1                                                매출원가
# 2                                               매출총이익
# 3                                             판매비와관리비
# 4                                                영업이익
# 5                                                기타수익
# 6                                                기타비용
# 7                                               지분법이익
# 8                                                금융수익
# 9                                                금융비용
# 10                                    법인세비용차감전순이익(손실)
# 11                                              법인세비용
# 12                                         계속영업이익(손실)
# 13                                          당기순이익(손실)
# ...

# %%
fs['is']
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)
#                                                                                            concept_id
# 0                                   ifrs-full_Revenue                                                  \
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                                     dart_OtherGains
# 6                                    dart_OtherLosses
# 7   entity00126380_udf_IS_2017102191515184_IncomeS...
# 8                             ifrs-full_FinanceIncome
# 9   entity00126380_udf_IS_2017102191643789_IncomeS...
# 10                      ifrs-full_ProfitLossBeforeTax
# 11     ifrs-full_IncomeTaxExpenseContinuingOperations
# 12       ifrs-full_ProfitLossFromContinuingOperations
# ...

# %% [markdown]
# ## 연결포괄손익계산서
# - 손익계산서는 기업이 제품을 얼마나 팔아서 얼마의 매출을 올렸고 이런저런 비용을 차감했더니 얼마가 남았다는 것을 보여주는 재무제표

# %%
fs['cis'].iloc[:,[1]]
# Out:
#    [D410000] Statement of comprehensive income - Consolidated financial statements (Unit: KRW)
#                                                                                       label_ko
# 0                                           당기순이익(손실)
# 1                                              기타포괄손익
# 2                          후속적으로 당기손익으로 재분류되지 않는 포괄손익
# 3                                 기타포괄손익-공정가치금융자산평가손익
# 4                          관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 5                                   순확정급여부채(자산) 재측정요소
# 6                             후속적으로 당기손익으로 재분류되는 포괄손익
# 7                          관계기업 및 공동기업의 기타포괄손익에 대한 지분
# 8                                         해외사업장환산외환차이
# 9                                    현금흐름위험회피파생상품평가손익
# 10                                              총포괄손익
# 11                                         지배기업 소유주지분
# 12                                              비지배지분

# %%
fs['cis']

# %% [markdown]
# ## 현금흐름표
# - 일정 기간 동안의 기업의 현금흐름을 나타내는 재무제표

# %%
fs['cf'].iloc[:,[1]]

# %%
fs['cf']

# %%
fs['is'].iloc[:,[1,6,7,8,9,10,11]]

# %%
df2 = fs['is']
df2['[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)']

# %%
fs['is'].iloc[:,[1,6,7,8,9,10,11]]

# %%
fs['bs']

# %%
type(fs)

# %%
type(fs['bs'])

# %%
bs_df = fs['bs']
bs_df

# %%
bs_title_df = bs_df.loc[:,'[D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)']

# %%
bs_title_df

# %% [markdown]
# ### 멀티 인덱스 공부합시다...

# %%
bs_price_df = bs_df.loc[:,['20221231','20211231','20201231','20191231','20181231']]

# %%
bs_price_df.columns
# Out:
# MultiIndex([('20221231', ('연결재무제표',)),
#             ('20211231', ('연결재무제표',)),
#             ('20201231', ('연결재무제표',)),
#             ('20191231', ('연결재무제표',)),
#             ('20181231', ('연결재무제표',))],
#            )

# %%
bs_price_df
# Out:
#                 20221231              20211231              20201231
#                (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0  218,470,581,000,000.0 218,163,185,000,000.0 198,215,579,000,000.0  \
# 1   49,680,710,000,000.0  39,031,415,000,000.0  29,382,578,000,000.0
# 2   65,102,886,000,000.0  81,708,986,000,000.0  92,441,703,000,000.0
# 3      414,610,000,000.0   3,369,034,000,000.0   2,757,111,000,000.0
# 4       29,080,000,000.0      40,757,000,000.0      71,451,000,000.0
# 5   35,721,563,000,000.0  40,713,415,000,000.0  30,965,058,000,000.0
# 6    6,149,209,000,000.0   4,497,257,000,000.0   3,604,539,000,000.0
# 7    2,867,823,000,000.0   2,336,252,000,000.0   2,266,100,000,000.0
# 8   52,187,866,000,000.0  41,384,404,000,000.0  32,043,145,000,000.0
# 9    6,316,834,000,000.0   5,081,665,000,000.0   3,754,462,000,000.0
# 10                   0.0                   0.0     929,432,000,000.0
# 11 229,953,926,000,000.0 208,457,973,000,000.0 180,020,139,000,000.0
# ...

# %%
bs_df.xs('연결재무제표',axis=1,level=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '연결재무제표'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
bs_df
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                        concept_id
# 0                             ifrs-full_CurrentAssets                                                              \
# 1                    ifrs-full_CashAndCashEquivalents
# 2   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 3   entity00126380_udf_BS_201851017339116_CurrentA...
# 4   ifrs-full_CurrentFinancialAssetsAtFairValueThr...
# 5                       dart_ShortTermTradeReceivable
# 6   entity00126380_udf_BS_201710182279121_CurrentA...
# 7   entity00126380_udf_BS_2017101822109437_Current...
# 8                               ifrs-full_Inventories
# 9                             dart_OtherCurrentAssets
# 10  entity00126380_udf_BS_20201022194537291_Curren...
# 11                         ifrs-full_NoncurrentAssets
# ...

# %%
bs_df = fs['bs']
cis_df = fs['cis']
is_df = fs['is']

# %%
bs_df.iloc[[43,51,52],:]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                        concept_id
# 43                            ifrs-full_IssuedCapital                                                              \
# 51                                   ifrs-full_Equity
# 52                     ifrs-full_EquityAndLiabilities
#
#
#    label_ko                      label_en            class0         class1
# 43      자본금                Issued capital  재무상태표 [abstract]  자본 [abstract]  \
# 51     자본총계                  Total equity  재무상태표 [abstract]  자본 [abstract]
# 52  부채와자본총계  Total liabilities and equity  재무상태표 [abstract]        부채와자본총계
#
#                                           20221231              20211231  ...
#         class2 class3 class4             (연결재무제표,)             (연결재무제표,)  ...
# ...

# %%
is_df.iloc[[0,4],:]
# Out:
#   [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)
#                                                                                           concept_id
# 0                                  ifrs-full_Revenue                                                  \
# 4                           dart_OperatingIncomeLoss
#
#
#   label_ko          label_en            class0   class1 class2
# 0  수익(매출액)    Revenue(Sales)  손익계산서 [abstract]  수익(매출액)   None  \
# 4     영업이익  Operating profit  손익계산서 [abstract]     영업이익   None
#
#       20220101-20221231     20210101-20211231     20200101-20201231
#               (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0 302,231,360,000,000.0 279,604,799,000,000.0 236,806,988,000,000.0  \
# 4  43,376,630,000,000.0  51,633,856,000,000.0  35,993,876,000,000.0
#
#       20190101-20191231     20180101-20181231     20170101-20171231
#               (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# ...

# %%
is_df.iloc[[0,4],:].drop(('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)','concept_id'),axis=1)
# Out:
#   [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)
#                                                                                             label_ko
# 0                                            수익(매출액)                                                  \
# 4                                               영업이익
#
#                                                           20220101-20221231
#            label_en            class0   class1 class2             (연결재무제표,)
# 0    Revenue(Sales)  손익계산서 [abstract]  수익(매출액)   None 302,231,360,000,000.0  \
# 4  Operating profit  손익계산서 [abstract]     영업이익   None  43,376,630,000,000.0
#
#       20210101-20211231     20200101-20201231     20190101-20191231
#               (연결재무제표,)             (연결재무제표,)             (연결재무제표,)
# 0 279,604,799,000,000.0 236,806,988,000,000.0 230,400,881,000,000.0  \
# 4  51,633,856,000,000.0  35,993,876,000,000.0  27,768,509,000,000.0
#
# ...

# %%
cis_df.iloc[[0],:]
# Out:
#   [D410000] Statement of comprehensive income - Consolidated financial statements (Unit: KRW)
#                                                                                    concept_id
# 0                               ifrs-full_ProfitLoss                                           \
#
#
#     label_ko                      label_en              class0     class1
# 0  당기순이익(손실)  Profit (loss) for the period  포괄손익계산서 [abstract]  당기순이익(손실)  \
#
#                    20220101-20221231    20210101-20211231
#   class2 class3            (연결재무제표,)            (연결재무제표,)
# 0   None   None 55,654,077,000,000.0 39,907,450,000,000.0  \
#
#      20200101-20201231    20190101-20191231    20180101-20181231
#              (연결재무제표,)            (연결재무제표,)            (연결재무제표,)
# 0 26,407,832,000,000.0 21,738,865,000,000.0 44,344,857,000,000.0  \
#
#      20170101-20171231    20160101-20161231    20150101-20151231
#              (연결재무제표,)            (연결재무제표,)            (연결재무제표,)
# ...

# %%
import pandas as pd

imsi_df = pd.concat([bs_df.iloc[[43,51,52],:],is_df.iloc[[0,4],:]])

# %%
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                        concept_id
# 43                            ifrs-full_IssuedCapital                                                              \
# 51                                   ifrs-full_Equity
# 52                     ifrs-full_EquityAndLiabilities
# 0                                                 NaN
# 4                                                 NaN
#
#
#    label_ko                      label_en            class0         class1
# 43      자본금                Issued capital  재무상태표 [abstract]  자본 [abstract]  \
# 51     자본총계                  Total equity  재무상태표 [abstract]  자본 [abstract]
# 52  부채와자본총계  Total liabilities and equity  재무상태표 [abstract]        부채와자본총계
# 0       NaN                           NaN               NaN            NaN
# ...

# %%
bs_df.iloc[[43,51,52],:]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                        concept_id
# 43                            ifrs-full_IssuedCapital                                                              \
# 51                                   ifrs-full_Equity
# 52                     ifrs-full_EquityAndLiabilities
#
#
#    label_ko                      label_en            class0         class1
# 43      자본금                Issued capital  재무상태표 [abstract]  자본 [abstract]  \
# 51     자본총계                  Total equity  재무상태표 [abstract]  자본 [abstract]
# 52  부채와자본총계  Total liabilities and equity  재무상태표 [abstract]        부채와자본총계
#
#                                           20221231              20211231  ...
#         class2 class3 class4             (연결재무제표,)             (연결재무제표,)  ...
# ...

# %%
imsi_df = bs_df.iloc[[43,51,52],:]
imsi_df.loc[:,
            [
                ('[D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)','label_ko')
               ,('20221231','(연결재무제표,)')
            ]
           ]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                          label_ko
# 43                                                자본금
# 51                                               자본총계
# 52                                            부채와자본총계

# %%
imsi_df.loc[:,('20221231','(연결재무제표,)')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\CapstonStockProject\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '(연결재무제표,)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
# <bound method DataFrame.info of    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)
#                                                                                                        concept_id
# 43                            ifrs-full_IssuedCapital                                                              \
# 51                                   ifrs-full_Equity
# 52                     ifrs-full_EquityAndLiabilities
#
#
#    label_ko                      label_en            class0         class1
# 43      자본금                Issued capital  재무상태표 [abstract]  자본 [abstract]  \
# 51     자본총계                  Total equity  재무상태표 [abstract]  자본 [abstract]
# 52  부채와자본총계  Total liabilities and equity  재무상태표 [abstract]        부채와자본총계
#
#                                           20221231              20211231  ...
#         class2 class3 class4             (연결재무제표,)             (연결재무제표,)  ...
# ...
