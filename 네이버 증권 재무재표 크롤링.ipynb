# %%
import requests
import pandas as pd

code = '005930'
url = f"https://finance.naver.com/item/main.naver?code={code}"

response = requests.get(url)

df = pd.read_html(response.text)[3]

# %%
df.set_index(df.columns[0],inplace=True)
df.index.rename('주요재무정보',inplace=True)
df.columns = df.columns.droplevel(2)
annual_date=pd.DataFrame(df).xs('최근 연간 실적',axis=1)
quarter_date=pd.DataFrame(df).xs('최근 분기 실적',axis=1)

# %%
df
# Out:
#              최근 연간 실적                                       최근 분기 실적
#               2020.12     2021.12     2022.12  2023.12(E)    2021.12
# 주요재무정보
# 매출액        2368070.00  2796048.00  3022314.00  2684186.00  765655.00  \
# 영업이익        359939.00   516339.00   433766.00    97356.00  138667.00
# 당기순이익       264078.00   399074.00   556541.00   109944.00  108379.00
# 영업이익률           15.20       18.47       14.35        3.63      18.11
# 순이익률            11.15       14.27       18.41        4.10      14.16
# ROE(지배주주)        9.98       13.92       17.07        3.09      13.92
# 부채비율            37.07       39.92       26.41         NaN      39.92
# 당좌비율           214.82      196.75      211.68         NaN     196.75
# 유보율          30692.79    33143.62    38144.29         NaN   33143.62
# EPS(원)        3841.00     5777.00     8057.00     1575.00    1567.00
# PER(배)          21.09       13.55        6.86       40.69      13.55
# BPS(원)       39406.00    43611.00    50817.00    51044.00   43611.00
# PBR(배)           2.06        1.80        1.09        1.26       1.80
# 주당배당금(원)      2994.00     1444.00     1444.00     1438.00        NaN
# 시가배당률(%)         3.70        1.84        2.61         NaN        NaN
# 배당성향(%)         77.95       25.00       17.92         NaN        NaN
#
#
#              2022.03    2022.06    2022.09    2022.12 2023.03(E)
# 주요재무정보
# 매출액        777815.00  772036.00  767817.00  704646.00  642012.00
# 영업이익       141214.00  140970.00  108520.00   43061.00   10001.00
# 당기순이익      113246.00  110988.00   93892.00  238414.00   15068.00
# 영업이익률          18.15      18.26      14.13       6.11       1.56
# 순이익률           14.56      14.38      12.23      33.84       2.35
# ROE(지배주주)      15.13      15.10      13.42      17.07        NaN
# 부채비율           39.34      36.64      36.35      26.41        NaN
# 당좌비율          202.26     219.39     226.19     211.68        NaN
# 유보율         34110.56   35054.68   35798.23   38144.29        NaN
# EPS(원)       1638.00    1613.00    1346.00    3460.00     182.00
# PER(배)         10.92       8.65       8.61       6.86     351.47
# BPS(원)      45106.00   46937.00   49387.00   50817.00        NaN
# PBR(배)          1.54       1.21       1.08       1.09        NaN
# 주당배당금(원)         NaN        NaN        NaN        NaN        NaN
# 시가배당률(%)         NaN        NaN        NaN        NaN        NaN
# 배당성향(%)          NaN        NaN        NaN        NaN        NaN
